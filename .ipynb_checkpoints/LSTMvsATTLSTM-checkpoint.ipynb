# %% [markdown]
# # Comparison between LSTMs and AttentionLSTMs

# %%
import numpy as np
import os, logging
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
logging.getLogger("tensorflow").setLevel(logging.CRITICAL)
logging.getLogger("tensorflow_hub").setLevel(logging.CRITICAL)
import keras as K

time_series = np.sin(np.linspace(1, 10*np.pi, 1000))
# Out:
# Using TensorFlow backend.

# %%
# Construct training set via sliding window

lag = 10
x = []
y = []

for i in range(len(time_series) - lag):
    x.append(time_series[i:i+lag])
    y.append(time_series[i+lag])

# batch, dimension, lag
x_train = np.array(x).reshape(-1, 1, lag)
y_train = np.array(y).reshape(-1, 1)

# %%
# Build ATT_LSTM model
input_layer = K.layers.Input(shape=(x_train.shape[1], x_train.shape[2]), dtype='float32') 
x = K.layers.LSTM(30, return_sequences=True)(input_layer)
attention_pre = K.layers.Dense(1, name='attention_vec')(x)   
attention_probs = K.layers.Softmax()(attention_pre)  
attention_mul = K.layers.Lambda(lambda x:x[0]*x[1])([attention_probs,x])
x = K.layers.Flatten()(attention_mul)
x = K.layers.Dense(20, activation='relu')(x)
preds = K.layers.Dense(1, activation='linear')(x)
model1 = K.models.Model(input_layer, preds)
model1.compile(loss='mse', optimizer=K.optimizers.Adam(0.01),metrics=['mse'])

# Build LSTM model
input_layer = K.layers.Input(shape=(x_train.shape[1], x_train.shape[2]), dtype='float32') 
x1 = K.layers.LSTM(30, return_sequences=True)(input_layer)
x2 = K.layers.LSTM(30, return_sequences=False)(x1)
x3 = K.layers.Dense(1)(x2)
model2 = K.models.Model(input_layer, x3)
model2.compile(loss='mse', optimizer=K.optimizers.Adam(0.01),metrics=['mse'])
# Out:
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
batch_size = 1
epochs = 50

model1.fit(x_train, y_train, batch_size=batch_size, epochs = epochs)
model2.fit(x_train, y_train, batch_size=batch_size, epochs = epochs)
# Out:
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/50
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/steven/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 990/990 [==============================] - 2s 2ms/step - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 2/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 3/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 4/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 5/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 6/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 7/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 8/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 9/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 10/50
# 990/990 [==============================] - 1s 1ms/step - loss: 9.3969e-04 - mean_squared_error: 9.3969e-04
# Epoch 11/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 12/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 13/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 14/50
# 990/990 [==============================] - 1s 1ms/step - loss: 7.1526e-04 - mean_squared_error: 7.1526e-04
# Epoch 15/50
# 990/990 [==============================] - 1s 1ms/step - loss: 6.8802e-04 - mean_squared_error: 6.8802e-04
# Epoch 16/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 17/50
# 990/990 [==============================] - 1s 1ms/step - loss: 6.8425e-04 - mean_squared_error: 6.8425e-04
# Epoch 18/50
# 990/990 [==============================] - 1s 1ms/step - loss: 6.4857e-04 - mean_squared_error: 6.4857e-04
# Epoch 19/50
# 990/990 [==============================] - 1s 1ms/step - loss: 7.3310e-04 - mean_squared_error: 7.3310e-04
# Epoch 20/50
# 990/990 [==============================] - 1s 1ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch
# 990/990 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 32/50
# 990/990 [==============================] - 2s 2ms/step - loss: 8.2126e-05 - mean_squared_error: 8.2126e-05
# Epoch 33/50
# 990/990 [==============================] - 2s 2ms/step - loss: 2.4532e-04 - mean_squared_error: 2.4532e-04
# Epoch 34/50
# 990/990 [==============================] - 2s 2ms/step - loss: 5.0847e-04 - mean_squared_error: 5.0847e-04
# Epoch 35/50
# 990/990 [==============================] - 2s 2ms/step - loss: 6.9851e-04 - mean_squared_error: 6.9851e-04
# Epoch 36/50
# 990/990 [==============================] - 2s 2ms/step - loss: 1.8747e-04 - mean_squared_error: 1.8747e-04
# Epoch 37/50
# 990/990 [==============================] - 2s 2ms/step - loss: 6.3511e-04 - mean_squared_error: 6.3511e-04
# Epoch 38/50
# 990/990 [==============================] - 2s 2ms/step - loss: 5.4743e-04 - mean_squared_error: 5.4743e-04
# Epoch 39/50
# 990/990 [==============================] - 2s 2ms/step - loss: 1.8956e-04 - mean_squared_error: 1.8956e-04
# Epoch 40/50
# 990/990 [==============================] - 2s 2ms/step - loss: 5.0360e-04 - mean_squared_error: 5.0360e-04
# Epoch 41/50
# 990/990 [==============================] - 2s 2ms/step - loss: 5.7289e-04 - mean_squared_error: 5.7289e-04
# Epoch 42/50
# 990/990 [==============================] - 2s 2ms/step - loss: 4.1034e-04 - mean_squared_error: 4.1034e-04
# Epoch 43/50
# 990/990 [==============================] - 2s 2ms/step - loss: 4.2620e-04 - mean_squared_error: 4.2620e-04
# Epoch 44/50
# 990/990 [==============================] - 2s 2ms/step - loss: 3.9002e-04 - mean_squared_error: 3.9002e-04
# Epoch 45/50
# 990/990 [==============================] - 2s 2ms/step - loss: 5.4613e-04 - mean_squared_error: 5.4613e-04
# Epoch 46/50
# 990/990 [==============================] - 2s 2ms/step - loss: 1.9486e-04 - mean_squared_error: 1.9486e-04
# Epoch 47/50
# 990/990 [==============================] - 2s 2ms/step - loss: 7.9961e-04 - mean_squared_error: 7.9961e-04
# Epoch 48/50
# 990/990 [==============================] - 2s 2ms/step - loss: 6.5570e-05 - mean_squared_error: 6.5570e-05
# Epoch 49/50
# 990/990 [==============================] - 2s 2ms/step - loss: 7.4155e-04 - mean_squared_error: 7.4155e-04
# Epoch 50/50
# 990/990 [==============================] - 2s 2ms/step - loss: 2.6539e-04 - mean_squared_error: 2.6539e-04

# %%
import copy

time_series1 = copy.deepcopy(time_series)
time_series2 = copy.deepcopy(time_series)

for i in range(200):
    # model1
    inp = time_series1[-lag:].reshape(-1, 1, lag)
    time_series1 = np.hstack([time_series1, model1.predict(inp)[0]])
    
    # model2
    inp = time_series2[-lag:].reshape(-1, 1, lag)
    time_series2 = np.hstack([time_series2, model2.predict(inp)[0]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.figure(figsize=(40,15))   
plt.plot(time_series, color='black', label='Training')
plt.plot(time_series1, 'r-', label='ATT_LSTM')
plt.plot(time_series2, 'b:', label='LSTM')
